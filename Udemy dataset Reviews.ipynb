# %% [markdown]
# # Udemy course dataset

# %%
import pandas as pd

# %%
df=pd.read_csv(r'E:\udemy_courses.csv')

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3678, step=1)

# %%
df.describe()
# Out:
#           course_id        price  num_subscribers   num_reviews  num_lectures  \
# count  3.678000e+03  3678.000000      3678.000000   3678.000000   3678.000000
# mean   6.759720e+05    66.049483      3197.150625    156.259108     40.108755
# std    3.432732e+05    61.005755      9504.117010    935.452044     50.383346
# min    8.324000e+03     0.000000         0.000000      0.000000      0.000000
# 25%    4.076925e+05    20.000000       111.000000      4.000000     15.000000
# 50%    6.879170e+05    45.000000       911.500000     18.000000     25.000000
# 75%    9.613555e+05    95.000000      2546.000000     67.000000     45.750000
# max    1.282064e+06   200.000000    268923.000000  27445.000000    779.000000
#
#        content_duration
# count       3678.000000
# mean           4.094517
# std            6.053840
# min            0.000000
# 25%            1.000000
# 50%            2.000000
# 75%            4.500000
# max           78.500000

# %%
df.isnull()
# Out:
#       course_id  course_title    url  is_paid  price  num_subscribers  \
# 0         False         False  False    False  False            False
# 1         False         False  False    False  False            False
# 2         False         False  False    False  False            False
# 3         False         False  False    False  False            False
# 4         False         False  False    False  False            False
# ...         ...           ...    ...      ...    ...              ...
# 3673      False         False  False    False  False            False
# 3674      False         False  False    False  False            False
# 3675      False         False  False    False  False            False
# 3676      False         False  False    False  False            False
# 3677      False         False  False    False  False            False
#
#       num_reviews  num_lectures  level  content_duration  published_timestamp  \
# ...

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %% [markdown]
# ### Q1 show all the course which are free?

# %%
df.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance

# %%
df.is_paid == False
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676    False
# 3677    False
# Name: is_paid, Length: 3678, dtype: bool

# %%
df[df.is_paid == False]
# Out:
#       course_id                                       course_title  \
# 95      1148774                    Options Trading 101: The Basics
# 103      133536               Stock Market Investing for Beginners
# 106      265960                      Fundamentals of Forex Trading
# 108      923616  Website Investing 101 - Buying & Selling Onlin...
# 112      191854                           Stock Market Foundations
# ...         ...                                                ...
# 3638     155640            Building a Search Engine in PHP & MySQL
# 3643     366720  CSS Image filters - The modern web images colo...
# 3651    1079078                             Drupal 8 Site Building
# 3665      21386               Beginner Photoshop to HTML5 and CSS3
# 3668     270976                             A how to guide in HTML
#
#                                                     url  is_paid  price  \
# 95    https://www.udemy.com/options-trading-101-the-...    False      0
# ...

# %% [markdown]
# ### Q2 show all the couse which are paid

# %% [markdown]
# ### Q3 What are all different subject for which udemy is offering ?

# %%
df.head(1)
# Out:
#    course_id                        course_title  \
# 0    1070968  Ultimate Investment Banking Course
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance

# %%
df.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
df.subject.nunique()
# Out:
# 4

# %% [markdown]
# ### Q4 Which Subject are maximun no of course?

# %%
df.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# ### Q5 which are top selling course?

# %%
df.sort_values('num_subscribers' , ascending = False)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# ...         ...                                                ...
# 1569     726314       Create Beautiful Image Maps for Your Website
# 1473     185526                             MicroStation - Células
# 1472     181268               Photoshop: Creando elemental de aire
# 1471     188584                        Letras en Adobe Illustrator
# 2405    1265814  ABRSM Grade III Piano Class - Handel Sonatina ...
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# ...

# %% [markdown]
# ### Q5 which are least selling course?

# %%
df.sort_values('num_subscribers' , ascending = True )
# Out:
#       course_id                                       course_title  \
# 885     1032648                               beginning accounting
# 456     1247992  Introduction to Project Management for Finance...
# 457     1251582              Best Practices in Corporate Budgeting
# 458     1258666                Financial Statement Auditing Cycles
# 459     1168172       Case studies on credit appraisal for bankers
# ...         ...                                                ...
# 3232     764164              The Complete Web Developer Course 2.0
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3230     625204                         The Web Developer Bootcamp
# 3032      59014                     Coding for Entrepreneurs Basic
# 2827      41295               Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 885         https://www.udemy.com/beginning_accounting/     True     20
# ...

# %% [markdown]
# ### Q7 Which  Data Analytics course are free?

# %%
df[(df.course_title.str.contains('Data Analytics')) & (df.is_paid == True) ]
# Out:
#       course_id                                       course_title  \
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 2875     902748  Introduction To Data Analytics Using Microsoft...
#
#                                                     url  is_paid  price  \
# 41    https://www.udemy.com/python-for-finance-inves...     True    195
# 2875      https://www.udemy.com/data-analytics-powerbi/     True     45
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 41               3811          278           103  All Levels
# 2875             1764           33            16  All Levels
#
#       content_duration published_timestamp         subject
# 41                 6.5 2017-03-30 22:17:09  Graphic Design
# 2875               1.5 2016-07-13 17:36:30  Graphic Design

# %% [markdown]
# ### Q8 List all the course  that are related to python?

# %%
df.head(2)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
#
#    num_subscribers  num_reviews  num_lectures       level  content_duration  \
# 0             2147           23            51  All Levels               1.5
# 1             2792          923           274  All Levels              39.0
#
#     published_timestamp           subject
# 0  2017-01-18T20:58:58Z  Business Finance
# 1  2017-03-09T16:34:20Z  Business Finance

# %%
df[df.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
df.course_title.str.contains('Python').value_counts()
# Out:
# False    3649
# True       29
# Name: course_title, dtype: int64

# %% [markdown]
# ### Q9 Show all the course of graphic design where price is below 100?

# %%
df[(df.subject == 'Graphic Design') & (df.price < 100) ]
# Out:
#       course_id                                       course_title  \
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 6        739964  Investing And Trading For Beginners: Mastering...
# 7        403100  Trading Stock Chart Patterns For Immediate, Ex...
# ...         ...                                                ...
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 1         https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
df[(df.subject == ' Graphic Design') & (df.price > 100)]
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, url, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
df[(df.subject == 'Graphic Design') & (df.price == 100) ]
# Out:
#       course_id                                       course_title  \
# 97      1233350                      Bitcoin Profits for Beginners
# 123     1100054  FOREX TRADING - Learn in a quick + profitable ...
# 132      262370      Accounting: Get Hired Without Work Experience
# 144      907444  SAP FICO For Beginners - A Guide to SAP Financ...
# 261      907716         International Tax  - Tax Beyond boundaries
# ...         ...                                                ...
# 3551    1012040  Bootstrap Bootcamp - Responsive web developmen...
# 3576    1250934  Display and analyze GIS data on the web with L...
# 3623    1170920         Node:js : Building Rest Apis with Sails.js
# 3661     761770                   Learn HTML5 Canvas for beginners
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
#
#                                                     url  is_paid  price  \
# 97    https://www.udemy.com/bitcoin-profits-for-begi...     True    100
# ...

# %% [markdown]
# ### Q10 what are the max no. of subscriber for each level of column?

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %% [markdown]
# # The End
